# %%
import pandas as pd

# %%
# 2 main datatype
series = pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red","Blue","White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sales.csv")

# %%
## Describing the data

# %%
# Attribute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([300,1500,111250])
car_prices.mean()
# Out:
# np.float64(37683.333333333336)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
car_sales["Doors"].mean()
# Out:
# np.float64(4.0)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.tail(1)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc

animals = pd.Series(["cat","dog","bird","panda","snake"], index=[0,3,9,8,3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
len(animals)
# Out:
# 5

# %%
# loc refers to index
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
# iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
animals.loc[]
# Out:
#   Cell In[35], line 1
#     animals.loc[]
#                 ^
# SyntaxError: invalid syntax

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make # this won't work when space is there in between
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales["Make"] == "Toyota"
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: Make, dtype: bool

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# if plot not showing up

# %marplorlib inline
import matplotlib.pylot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 4
#       1 # if plot not showing up
#       2
#       3 # %marplorlib inline
# ----> 4 import matplotlib.pylot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
car_sales["Odometer (KM)"].plot()

# %%
# Groupby

car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 car_sales["Price"].plot()
#
# File ~/git/data-science-ml-notes/introduction/env/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/git/data-science-ml-notes/introduction/env/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','')

# car_sales["Price"] = car_sales["Price"].str.replace(r'[$,]', '')
car_sales["Price"] = car_sales["Price"].str.replace(r'[$,]', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 4
#       1 # car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','')
#       2
#       3 # car_sales["Price"] = car_sales["Price"].str.replace(r'[$,]', '')
# ----> 4 car_sales["Price"] = car_sales["Price"].str.replace(r'[$,]', '').astype(float)
#
# File ~/git/data-science-ml-notes/introduction/env/lib/python3.13/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
car_sales

# %%
# Import data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[$,]', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace(r'[$,]', '').astype(float)
#
# File ~/git/data-science-ml-notes/introduction/env/lib/python3.13/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(',','')
car_sales["Price"] = car_sales["Price"].str.replace('$','').astype(float)

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
# Out:
# /var/folders/8h/m_8j1qhx48q7b1s32_hns8cw0000gn/T/ipykernel_51352/3620729653.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
seats_column = pd.Series([5,5,5,5,5])

car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales.fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.5,6.4,6.5,4.3,8.7]
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.5
# 8  toyota  White          60000      4   6250.0    5.0             4.3
# 9  nissan  White          31600      4   9700.0    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.5
# 8  toyota  White          60000      4   6250.0    5.0             4.3
# 9  nissan  White          31600      4   9700.0    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road Safety  Total fuel used
# 0            11253.225                 4                True        11253.225
# ...

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.5
# 8  toyota  White          60000      4   6250.0    5.0             4.3
# 9  nissan  White          31600      4   9700.0    5.0             8.7
#
#    Total fuel used (L)  Number of wheels
# 0            11253.225                 4
# 1             8086.708                 4
# 2             1627.450                 4
# ...

# %%
car_sales["Passed road Safety"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                  float64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road Safety        bool
# dtype: object

# %%
car_sales.drop("Total fuel used", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 car_sales.drop("Total fuel used", axis=1)
#
# File ~/git/data-science-ml-notes/introduction/env/lib/python3.13/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"] / 100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.5
# 8  toyota  White          60000      4   6250.0    5.0             4.3
# 9  nissan  White          31600      4   9700.0    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road Safety  Total fuel used
# 0            11253.225                 4                True        11253.225
# ...

# %%
car_sales.drop("Total fuel used", axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 5  toyota  Green          99213      4   4500.0    5.0             4.5
# 6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7   honda   Blue          54738      4   7000.0    5.0             6.5
# 8  toyota  White          60000      4   6250.0    5.0             4.3
# 9  nissan  White          31600      4   9700.0    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 7   honda   Blue          54738      4   7000.0    5.0             6.5
# 2  toyota   Blue          32549      3   7000.0    5.0             5.0
# 4  nissan  White         213095      4   3500.0    5.0             8.7
# 1   honda    Red          87899      4   5000.0    5.0             9.2
# 5  toyota  Green          99213      4   4500.0    5.0             4.5
# 9  nissan  White          31600      4   9700.0    5.0             8.7
# 6   honda   Blue          45698      4   7500.0    5.0             6.4
# 0  toyota  White         150043      4   4000.0    5.0             7.5
# 8  toyota  White          60000      4   6250.0    5.0             4.3
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# 7             3557.970                 4                True
# 2             1627.450                 4                True
# ...

# %%
# selecting 20 percent of the data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 3     bmw  Black          11179      5  22000.0    5.0             9.6
# 8  toyota  White          60000      4   6250.0    5.0             4.3
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# 3             1073.184                 4                True
# 8             2580.000                 4                True

# %%
car_sales_shuffled.reset_index(inplace=True)

# %%
car_sales_shuffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      0   honda   Blue          54738      4   7000.0    5.0             6.5
# 1      1  toyota   Blue          32549      3   7000.0    5.0             5.0
# 2      2  nissan  White         213095      4   3500.0    5.0             8.7
# 3      3   honda    Red          87899      4   5000.0    5.0             9.2
# 4      4  toyota  Green          99213      4   4500.0    5.0             4.5
# 5      5  nissan  White          31600      4   9700.0    5.0             8.7
# 6      6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7      7  toyota  White         150043      4   4000.0    5.0             7.5
# 8      8  toyota  White          60000      4   6250.0    5.0             4.3
# 9      9     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# ...

# %%
car_sales_shuffled.reset_index(inplace=True, drop=True)

# %%
car_sales_shuffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0      0   honda   Blue          54738      4   7000.0    5.0             6.5
# 1      1  toyota   Blue          32549      3   7000.0    5.0             5.0
# 2      2  nissan  White         213095      4   3500.0    5.0             8.7
# 3      3   honda    Red          87899      4   5000.0    5.0             9.2
# 4      4  toyota  Green          99213      4   4500.0    5.0             4.5
# 5      5  nissan  White          31600      4   9700.0    5.0             8.7
# 6      6   honda   Blue          45698      4   7500.0    5.0             6.4
# 7      7  toyota  White         150043      4   4000.0    5.0             7.5
# 8      8  toyota  White          60000      4   6250.0    5.0             4.3
# 9      9     bmw  Black          11179      5  22000.0    5.0             9.6
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000.0    5.0             7.5
# 1   honda    Red      54936.875      4   5000.0    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000.0    5.0             5.0
# 3     bmw  Black       6986.875      5  22000.0    5.0             9.6
# 4  nissan  White     133184.375      4   3500.0    5.0             8.7
# 5  toyota  Green      62008.125      4   4500.0    5.0             4.5
# 6   honda   Blue      28561.250      4   7500.0    5.0             6.4
# 7   honda   Blue      34211.250      4   7000.0    5.0             6.5
# 8  toyota  White      37500.000      4   6250.0    5.0             4.3
# 9  nissan  White      19750.000      4   9700.0    5.0             8.7
#
#    Total fuel used (L)  Number of wheels  Passed road Safety
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...
